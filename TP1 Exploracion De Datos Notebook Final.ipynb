# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
trips = pd.read_csv('tp_bike/trip.csv')

# %%
weather = pd.read_csv('tp_bike/weather.csv')

# %%
station = pd.read_csv('tp_bike/station.csv')

# %%
trips.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
#
#    end_station_id  bike_id subscription_type zip_code
# 0              66      520        Subscriber    94127
# 1              10      661        Subscriber    95138
# 2              27       48        Subscriber    97214

# %% [markdown]
# # Depuracion de datos

# %%
#separo las fechas de las horas
fechaYhora = trips['start_date'].str.split(' ')
fecha = fechaYhora.map(lambda x: x[0])
hora = fechaYhora.map(lambda x: x[1])
trips = trips.assign(date_start = fecha, time_start = hora)

# %%
#IDEM pero con la fecha final
fechaYhora = trips['end_date'].str.split(' ')
fecha = fechaYhora.map(lambda x: x[0])
hora = fechaYhora.map(lambda x: x[1])
trips = trips.assign(date_end = fecha, time_end = hora)

# %%
#le cambio el formato a las fechas
import calendar
trips['date_start'] = pd.to_datetime(trips['date_start'])
trips['date_end'] = pd.to_datetime(trips['date_end'])

# %%
#Creacion de columna por nombre de dia
trips['weekday'] = trips['date_start'].map(lambda x: x.weekday_name)

# %%
#Creacion de columna por hora
trips['hour'] = pd.to_datetime(trips['time_start'], format = '%H:%M', errors = 'coerce').dt.hour

# %%
#Plots sobre la Cantidad de alquileres por hora
plt.figure()
plt.title('Cantidad de Alquileres de bicicletas por hora', color = 'black')
trips['hour'].value_counts().sort_index().plot(kind = 'bar', figsize = (10,6))
plt.xlabel('Hora')
plt.ylabel('Cantidad bicicletas alquiladas');

# %%
# Cantidad de viajes segun dia, ordenados por dia de la semana
diasDeSemana = trips['weekday'].value_counts()
diasDeSemana = diasDeSemana.reindex(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
diasDeSemana
# Out:
# Monday       115873
# Tuesday      122259
# Wednesday    120201
# Thursday     119089
# Friday       109361
# Saturday      44785
# Sunday        38391
# Name: weekday, dtype: int64

# %%
#cantidad de alquileres por dia
plt.figure()
plt.title('Cantidad de Alquileres de bicicletas por dia', color = 'black')
diasDeSemana.plot(kind = 'bar', figsize = (12,5))
plt.ylabel('Cantidad de bicicletas alquiladas')
plt.xlabel('Dia');

# %% [markdown]
# # Analisis atributo bike_id

# %%
top = trips.loc[:,['bike_id','duration']].groupby('bike_id').agg(['count','mean'])
top_ten = top.sort_values(('duration','count'),ascending=False).reset_index()

# %%
top_ten.head(3)
#el bike_id 392 es el que mas viajes tiene
# Out:
#   bike_id duration
#              count        mean
# 0     392     2061  868.256186
# 1     489     1975  883.958481
# 2     558     1955  884.573402

# %%
trips.loc[trips.bike_id == 392,:].sort_values('duration',ascending=False)[0:5]
# Out:
#             id  duration       start_date  \
# 341835  879402     47545   8/6/2015 18:46
# 660744  445597     42483   9/10/2014 6:45
# 19116    30245     32255   9/22/2013 8:36
# 388844  817974     29919   6/23/2015 8:04
# 567066  577385     29430  12/16/2014 8:51
#
#                               start_station_name  start_station_id  \
# 341835                            Market at 10th                67
# 660744  San Francisco Caltrain (Townsend at 4th)                70
# 19116                         Powell Street BART                39
# 388844  San Francisco Caltrain (Townsend at 4th)                70
# 567066   San Francisco Caltrain 2 (330 Townsend)                69
#
#                 end_date                          end_station_name  \
# 341835     8/7/2015 7:59                  Commercial at Montgomery
# 660744   9/10/2014 18:34  San Francisco Caltrain (Townsend at 4th)
# 19116    9/22/2013 17:34                  Commercial at Montgomery
# 388844   6/23/2015 16:23  San Francisco Caltrain (Townsend at 4th)
# 567066  12/16/2014 17:01                         Market at Sansome
#
#         end_station_id  bike_id subscription_type zip_code date_start  \
# 341835              45      392          Customer    94133 2015-08-06
# 660744              70      392          Customer    90034 2014-09-10
# 19116               45      392          Customer      NaN 2013-09-22
# 388844              70      392        Subscriber    94010 2015-06-23
# 567066              77      392        Subscriber    94086 2014-12-16
#
#        time_start   date_end time_end    weekday  hour
# 341835      18:46 2015-08-07     7:59   Thursday    18
# 660744       6:45 2014-09-10    18:34  Wednesday     6
# 19116        8:36 2013-09-22    17:34     Sunday     8
# 388844       8:04 2015-06-23    16:23    Tuesday     8
# 567066       8:51 2014-12-16    17:01    Tuesday     8

# %%
#1 bici con mas viajes
plt.title('Histograma de duracion de la bicicleta con mas viajes (id 392)')
trips.loc[trips.bike_id == 392,:].loc[trips.duration <=4000]['duration'].hist(bins=100,figsize=(12,7))
plt.xlabel('Duracion')
plt.ylabel('Cantidad');

# %%
# 2° bici con mas viajes
plt.title('Histograma de duracion de la bicicleta con mas viajes (id 489)')
trips.loc[trips.bike_id == 489,:].loc[trips.duration <=4000]['duration'].hist(bins=100,figsize=(12,7))
plt.xlabel('Duracion')
plt.ylabel('Cantidad');

# %%
# 3° bici con mas viajes
plt.title('Histograma de duracion de la bicicleta con mas viajes (id 558)')
trips.loc[trips.bike_id == 558,:].loc[trips.duration <=4000]['duration'].hist(bins=100,figsize=(12,7))
plt.xlabel('Duracion')
plt.ylabel('Cantidad');

# %%
plt.title('Histograma de duracion de las tres bicicletas con mas viajes')
trips.loc[trips.bike_id == 392,:].loc[trips.duration <=4000]['duration'].hist(bins=100,alpha=0.3,figsize=(12,7),color='yellow',label='id 392')
trips.loc[trips.bike_id == 558,:].loc[trips.duration <=4000]['duration'].hist(bins=100,alpha=0.3,figsize=(12,7),color='blue',label='id 558')
trips.loc[trips.bike_id == 489,:].loc[trips.duration <=4000]['duration'].hist(bins=100,alpha=0.3,figsize=(12,7),color='green',label='id 482')
plt.xlabel('Duracion')
plt.ylabel('Cantidad')
plt.legend();

# %%
# Separo meses por nombre
trips['Month'] = trips['date_start'].map(lambda x: x.strftime('%B'))

# %%
# Me fijo cada mes por los tres anios 2013,2014,2015
mesPor2013 = trips.loc[trips.start_date.str.contains('2013'),['Month']]
mesPor2013 = mesPor2013['Month'].value_counts()
mesPor2014 = trips.loc[trips.start_date.str.contains('2014'),['Month']]
mesPor2014 = mesPor2014['Month'].value_counts()
mesPor2015 = trips.loc[trips.start_date.str.contains('2015'),['Month']]
mesPor2015 = mesPor2015['Month'].value_counts()

# %%
#Arreglo los indices
mesPor2014 = mesPor2014\
    .reindex(['January','February','March','April','May','June','July','August','September','October','November','December'])
mesPor2013 = mesPor2013.reindex\
(['January','February','March','April','May','June','July','August','September','October','November','December'],fill_value=0)
mesPor2015 = mesPor2015.reindex(\
['January','February','March','April','May','June','July','August','September','October','November','December'],fill_value=0)

# %%
plt.figure()
plt.title('Cantidad de viajes segun anio y meses')
mesPor2013.plot('bar',position=1,width=0.1,label='2013',figsize=(15,5))
mesPor2014.plot('bar',position=0,color='green',width=0.13,label='2014',figsize=(15,5))
mesPor2015.plot('bar',position=2,color='black',width=0.13,label='2015',figsize=(15,5))
plt.legend()
plt.xlabel('Mes')
plt.ylabel('Cantidad de viajes');

# %% [markdown]
# # Subscriber y Customers

# %%
numSuscripcion = trips['subscription_type'].value_counts()
numSuscripcion
# Out:
# Subscriber    566746
# Customer      103213
# Name: subscription_type, dtype: int64

# %%
plt.title("Cantidad de alquileres de los clientes vs no clientes")
numSuscripcion.plot(kind = 'bar', figsize = (10,6));

# %%
trips.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
#
#    end_station_id  bike_id subscription_type zip_code date_start time_start  \
# 0              66      520        Subscriber    94127 2013-08-29      14:13
# 1              10      661        Subscriber    95138 2013-08-29      14:42
# 2              27       48        Subscriber    97214 2013-08-29      10:16
#
#     date_end time_end   weekday  hour   Month
# 0 2013-08-29    14:14  Thursday    14  August
# 1 2013-08-29    14:43  Thursday    14  August
# 2 2013-08-29    10:17  Thursday    10  August

# %%
trips['month_start'] = trips['date_start'].map(lambda x: x.month)

# %%
#Cambio de nombre de las columnas anteriores
trips = trips.rename(columns={'weekday': 'day_start','hour' : 'hour_start','Month' : 'month_start_name'})

# %%
trips.sort_values('duration', ascending=False)[0:3]
# Out:
#             id  duration       start_date           start_station_name  \
# 573566  568474  17270400  12/6/2014 21:59     South Van Ness at Market
# 382718  825850   2137000  6/28/2015 21:50            Market at Sansome
# 440339  750192   1852590    5/2/2015 6:17  San Antonio Shopping Center
#
#         start_station_id         end_date  \
# 573566                66  6/24/2015 20:18
# 382718                77  7/23/2015 15:27
# 440339                31  5/23/2015 16:53
#
#                                      end_station_name  end_station_id  \
# 573566                                  2nd at Folsom              62
# 382718  Yerba Buena Center of the Arts (3rd @ Howard)              68
# 440339               Castro Street and El Camino Real              32
#
#         bike_id subscription_type zip_code date_start time_start   date_end  \
# 573566      535          Customer    95531 2014-12-06      21:59 2015-06-24
# 382718      466          Customer    97213 2015-06-28      21:50 2015-07-23
# 440339      680        Subscriber    94024 2015-05-02       6:17 2015-05-23
#
#        time_end day_start  hour_start month_start_name  month_start
# 573566    20:18  Saturday          21         December           12
# 382718    15:27    Sunday          21             June            6
# 440339    16:53  Saturday           6              May            5

# %%
#Subscriber
tripSub = trips.loc[trips.subscription_type.str.contains('Subscriber')]\
               .loc[trips.duration >= 10,:].loc[trips.duration <=86400] #un dia

# %%
plt.title('Tiempo promedio que viaja un Subscriptor para cada mes',color='black')
tripSub.groupby('hour_start').mean()['duration'].plot(figsize=(10,6));
plt.ylabel('Tiempo promedio de viaje')
plt.xlabel('meses');

# %%
tripCus = trips.loc[trips.subscription_type.str.contains('Customer')]\
               .loc[trips.duration >= 60,:].loc[trips.duration <=86400] #un dia

# %%
plt.title('Tiempo promedio que viaja un Customer para cada mes',color='black')
tripCus.groupby('month_start').mean()['duration'].plot(figsize=(10,6));
plt.ylabel('Tiempo promedio de viaje')
plt.xlabel('meses');

# %% [markdown]
# # Cantidad de viajes entre estaciones

# %%
#cambio zip code a numerico
trips.zip_code = trips.zip_code.str.replace('nil','')
trips.zip_code = pd.to_numeric(trips.zip_code,errors='coerce')
trips.dtypes
# Out:
# id                             int64
# duration                       int64
# start_date                    object
# start_station_name            object
# start_station_id               int64
# end_date                      object
# end_station_name              object
# end_station_id                 int64
# bike_id                        int64
# subscription_type             object
# zip_code                     float64
# date_start            datetime64[ns]
# time_start                    object
# date_end              datetime64[ns]
# time_end                      object
# day_start                     object
# hour_start                     int64
# month_start_name              object
# month_start                    int64
# dtype: object

# %%
##Cantidad de Viajes por ZIP CODE
trips.groupby('zip_code').count().sort_values('start_station_name',ascending=False).head(10)
# Out:
#              id  duration  start_date  start_station_name  start_station_id  \
# zip_code
# 94107.0   78704     78704       78704               78704             78704
# 94105.0   42672     42672       42672               42672             42672
# 94133.0   31359     31359       31359               31359             31359
# 94103.0   26673     26673       26673               26673             26673
# 94111.0   21409     21409       21409               21409             21409
# 94102.0   19757     19757       19757               19757             19757
# 94109.0   13989     13989       13989               13989             13989
# 95112.0   11564     11564       11564               11564             11564
# 94117.0    9851      9851        9851                9851              9851
# 94158.0    9180      9180        9180                9180              9180
#
#           end_date  end_station_name  end_station_id  bike_id  \
# zip_code
# 94107.0      78704             78704           78704    78704
# 94105.0      42672             42672           42672    42672
# 94133.0      31359             31359           31359    31359
# 94103.0      26673             26673           26673    26673
# 94111.0      21409             21409           21409    21409
# 94102.0      19757             19757           19757    19757
# 94109.0      13989             13989           13989    13989
# 95112.0      11564             11564           11564    11564
# 94117.0       9851              9851            9851     9851
# 94158.0       9180              9180            9180     9180
#
#           subscription_type  date_start  time_start  date_end  time_end  \
# zip_code
# 94107.0               78704       78704       78704     78704     78704
# 94105.0               42672       42672       42672     42672     42672
# 94133.0               31359       31359       31359     31359     31359
# 94103.0               26673       26673       26673     26673     26673
# 94111.0               21409       21409       21409     21409     21409
# 94102.0               19757       19757       19757     19757     19757
# 94109.0               13989       13989       13989     13989     13989
# 95112.0               11564       11564       11564     11564     11564
# 94117.0                9851        9851        9851      9851      9851
# 94158.0                9180        9180        9180      9180      9180
#
#           day_start  hour_start  month_start_name  month_start
# zip_code
# 94107.0       78704       78704             78704        78704
# 94105.0       42672       42672             42672        42672
# 94133.0       31359       31359             31359        31359
# 94103.0       26673       26673             26673        26673
# 94111.0       21409       21409             21409        21409
# 94102.0       19757       19757             19757        19757
# 94109.0       13989       13989             13989        13989
# 95112.0       11564       11564             11564        11564
# 94117.0        9851        9851              9851         9851
# 94158.0        9180        9180              9180         9180

# %%
#Localizo las estaciones que empezaron en una estacion y terminaron en otra 
# Saco las que tienen pocas (ecuacion mas peligrosa) los que tienen mas de 500 viajes
#Saco el top 10 de las duraciones por nombre de estacion inicial
viajesDistintasEstaciones = trips.loc[trips.start_station_name != trips.end_station_name,['start_station_name','duration']]
agrupadoViajesDistintos = viajesDistintasEstaciones.groupby('start_station_name').agg(['count','mean'])
topDuracionViajesEntreEstaciones = agrupadoViajesDistintos[agrupadoViajesDistintos['duration','count'] > 500 ]\
    ['duration','mean'].sort_values(ascending=False)
topDuracionViajesEntreEstaciones
# Out:
# start_station_name
# University and Emerson                           3974.757282
# California Ave Caltrain Station                  2612.371464
# South Van Ness at Market                         2312.118846
# Rengstorff Avenue / California Street            2210.418989
# San Jose Civic Center                            2209.133001
# Palo Alto Caltrain Station                       2169.851895
# Park at Olive                                    2120.227273
# San Antonio Shopping Center                      1773.581182
# Arena Green / SAP Center                         1631.973396
# Washington at Kearney                            1585.978308
# San Francisco City Hall                          1537.388798
# Redwood City Caltrain Station                    1475.982130
# Embarcadero at Vallejo                           1441.692840
# Japantown                                        1415.693452
# Castro Street and El Camino Real                 1410.933831
# Washington at Kearny                             1404.127523
# Cowper at University                             1386.835685
# Santa Clara County Civic Center                  1366.869340
# SJSU 4th at San Carlos                           1242.233962
# Harry Bridges Plaza (Ferry Building)             1231.266626
# Embarcadero at Sansome                           1167.140549
# Powell at Post (Union Square)                    1123.201819
# Powell Street BART                               1116.140959
# Paseo de San Antonio                             1104.727447
# San Antonio Caltrain Station                     1087.361335
# Adobe on Almaden                                 1060.053435
# SJSU - San Salvador at 9th                       1058.390796
# Market at 4th                                    1042.608405
# Grant Avenue at Columbus Avenue                  1025.871738
# MLK Library                                      1008.571121
#                                                     ...
# San Pedro Square                                  888.661029
# Clay at Battery                                   874.481270
# Market at 10th                                    871.718352
# Post at Kearny                                    862.015118
# Market at Sansome                                 858.456642
# Embarcadero at Bryant                             855.262104
# Yerba Buena Center of the Arts (3rd @ Howard)     808.516799
# Davis at Jackson                                  806.704610
# Steuart at Market                                 797.402193
# Mountain View Caltrain Station                    797.288065
# Beale at Market                                   762.508412
# San Francisco Caltrain (Townsend at 4th)          761.180193
# San Jose Diridon Caltrain Station                 760.271485
# Mountain View City Hall                           759.846071
# Embarcadero at Folsom                             759.233280
# Broadway St at Battery St                         744.757049
# 5th at Howard                                     743.677282
# 2nd at Townsend                                   727.971337
# Spear at Folsom                                   725.546448
# Commercial at Montgomery                          711.759192
# St James Park                                     688.410031
# Howard at 2nd                                     683.483109
# Ryland Park                                       662.690080
# San Francisco Caltrain 2 (330 Townsend)           658.222382
# 2nd at South Park                                 654.590001
# Evelyn Park and Ride                              642.182919
# Townsend at 7th                                   639.200481
# Temporary Transbay Terminal (Howard at Beale)     614.675719
# Santa Clara at Almaden                            609.685504
# 2nd at Folsom                                     540.350261
# Name: (duration, mean), dtype: float64

# %%
#Hago un plot de lo anterior
plt.figure()
plt.title('Top 10 de las duraciones entre viajes de distintas estaciones')
topDuracionViajesEntreEstaciones = topDuracionViajesEntreEstaciones.head(10)
topDuracionViajesEntreEstaciones.plot('bar',figsize= (16, 6))
plt.xlabel('Estacion inicial')
plt.ylabel('Promedio de duracion de todos los viajes');

# %%
##Cantidad de viajes de una estacion a la misma
plt.figure('Top 10 cantidad de viajes desde una estacion a la misma')
trips.loc[trips.start_station_name == trips.end_station_name,'start_station_name'].value_counts().head(10)\
    .plot('bar',figsize=(14,6))
plt.ylabel('Cantidad')
plt.xlabel('Estacion')

# %% [markdown]
# # Cantidad de viajes entre distintas estaciones por ej: NY -> LA o LA -> NY

# %%
#Cantidad de viajes entre distintas estaciones por  ej: NY -> LA o LA -> NY
entreEstacionesDistintas = trips.loc\
    [trips.start_station_name != trips.end_station_name,['start_station_name','end_station_name']]

# %%
# creo una nueva columna iniciandizandolas en 1
entreEstacionesDistintas['contador'] = 1

# %%
## Cambio de lugar las estaciones de comienzo y las finaless
entreEstacionesDistintasFinales = pd.DataFrame(entreEstacionesDistintas)
entreEstacionesDistintasFinales.rename(columns=\
                            {'start_station_name':'end_station_name','end_station_name':'start_station_name'},inplace=True)

# %%
#Creo un contador de estaciones iniciales distintas de por ej: LA -> NY 
contadorEstacionesDistintasIniciales = entreEstacionesDistintas.groupby(['start_station_name','end_station_name']).sum()\
        .reset_index().sort_values('contador',ascending=False)

# %%
#Creo un contador de estaciones finales distintas de por ej: NY -> LA 
contadorEstacionesDistintasFinales = entreEstacionesDistintasFinales.groupby(['start_station_name','end_station_name'])\
                            .count().reset_index().sort_values('contador',ascending=False)
contadorEstacionesDistintasFinales
# Out:
#                                  start_station_name  \
# 1714                                Townsend at 7th
# 532                          Embarcadero at Sansome
# 1307       San Francisco Caltrain (Townsend at 4th)
# 684            Harry Bridges Plaza (Ferry Building)
# 87                                  2nd at Townsend
# 1627                              Steuart at Market
# 1280       San Francisco Caltrain (Townsend at 4th)
# 102                                 2nd at Townsend
# 865                               Market at Sansome
# 707            Harry Bridges Plaza (Ferry Building)
# 1306       San Francisco Caltrain (Townsend at 4th)
# 1677  Temporary Transbay Terminal (Howard at Beale)
# 1344        San Francisco Caltrain 2 (330 Townsend)
# 1305       San Francisco Caltrain (Townsend at 4th)
# 1106                             Powell Street BART
# 55                                2nd at South Park
# 694            Harry Bridges Plaza (Ferry Building)
# 1287       San Francisco Caltrain (Townsend at 4th)
# 547                          Embarcadero at Sansome
# 1285       San Francisco Caltrain (Townsend at 4th)
# 506                           Embarcadero at Folsom
# 134                                   5th at Howard
# 1617                              Steuart at Market
# 1641                              Steuart at Market
# 1336        San Francisco Caltrain 2 (330 Townsend)
# 1288       San Francisco Caltrain (Townsend at 4th)
# 317               Civic Center BART (7th at Market)
# 1693                                Townsend at 7th
# 962                         Mountain View City Hall
# 890                               Market at Sansome
# ...                                             ...
# 1263                    San Antonio Shopping Center
# 312               Civic Center BART (7th at Market)
# 1215                     SJSU - San Salvador at 9th
# 154                                Adobe on Almaden
# 1161                  Redwood City Caltrain Station
# 937                                      Mezes Park
# 1173                    Redwood City Public Library
# 1744                          Washington at Kearney
# 1737                         University and Emerson
# 1730                         University and Emerson
# 1182          Rengstorff Avenue / California Street
# 161                        Arena Green / SAP Center
# 171                        Arena Green / SAP Center
# 1193          Rengstorff Avenue / California Street
# 182                                 Beale at Market
# 257                 California Ave Caltrain Station
# 308               Civic Center BART (7th at Market)
# 258                 California Ave Caltrain Station
# 870                               Market at Sansome
# 260                 California Ave Caltrain Station
# 265                 California Ave Caltrain Station
# 270                 California Ave Caltrain Station
# 275                Castro Street and El Camino Real
# 1250                   San Antonio Caltrain Station
# 277                Castro Street and El Camino Real
# 1253                   San Antonio Caltrain Station
# 1257                    San Antonio Shopping Center
# 847                                   Market at 4th
# 307               Civic Center BART (7th at Market)
# 1444                        San Mateo County Center
#
#                                    end_station_name  contador
# 1714        San Francisco Caltrain 2 (330 Townsend)      6216
# 532            Harry Bridges Plaza (Ferry Building)      6164
# 1307                                Townsend at 7th      5041
# 684                                 2nd at Townsend      4839
# 87             Harry Bridges Plaza (Ferry Building)      4357
# 1627                         Embarcadero at Sansome      4269
# 1280                          Embarcadero at Folsom      3967
# 102                               Steuart at Market      3903
# 865                               2nd at South Park      3627
# 707        San Francisco Caltrain (Townsend at 4th)      3622
# 1306  Temporary Transbay Terminal (Howard at Beale)      3526
# 1677       San Francisco Caltrain (Townsend at 4th)      3510
# 1344                                Townsend at 7th      3495
# 1305                              Steuart at Market      3477
# 1106        San Francisco Caltrain 2 (330 Townsend)      3438
# 55                                Market at Sansome      3427
# 694                          Embarcadero at Sansome      3231
# 1287                                 Market at 10th      3190
# 547                               Steuart at Market      3116
# 1285           Harry Bridges Plaza (Ferry Building)      3033
# 506        San Francisco Caltrain (Townsend at 4th)      3031
# 134         San Francisco Caltrain 2 (330 Townsend)      3005
# 1617                                2nd at Townsend      2877
# 1641       San Francisco Caltrain (Townsend at 4th)      2866
# 1336                             Powell Street BART      2854
# 1288                                  Market at 4th      2797
# 317                                 Townsend at 7th      2698
# 1693              Civic Center BART (7th at Market)      2672
# 962                  Mountain View Caltrain Station      2666
# 890        San Francisco Caltrain (Townsend at 4th)      2598
# ...                                             ...       ...
# 1263                             Powell Street BART         1
# 312                           San Jose Civic Center         1
# 1215                    Redwood City Medical Center         1
# 154                      San Jose Government Center         1
# 1161                   San Antonio Caltrain Station         1
# 937                                 Beale at Market         1
# 1173                           Cowper at University         1
# 1744                      Broadway St at Battery St         1
# 1737                        San Mateo County Center         1
# 1730                             Powell Street BART         1
# 1182                               Adobe on Almaden         1
# 161                            Evelyn Park and Ride         1
# 171                      San Jose Government Center         1
# 1193              San Jose Diridon Caltrain Station         1
# 182                 California Ave Caltrain Station         1
# 257                                Broadway at Main         1
# 308                     San Antonio Shopping Center         1
# 258                Castro Street and El Camino Real         1
# 870                 California Ave Caltrain Station         1
# 260                                      Mezes Park         1
# 265                   Redwood City Caltrain Station         1
# 270                        Stanford in Redwood City         1
# 275                      Palo Alto Caltrain Station         1
# 1250                  Redwood City Caltrain Station         1
# 277                     Redwood City Public Library         1
# 1253       San Francisco Caltrain (Townsend at 4th)         1
# 1257                           Cowper at University         1
# 847                            Paseo de San Antonio         1
# 307                   Redwood City Caltrain Station         1
# 1444                          Embarcadero at Bryant         1
#
# [1843 rows x 3 columns]

# %% [markdown]
# # Merge

# %%
# Los mergeo entre estaciones iniciales y finales que ya fueron sumados sus contadores, de forma INNER para que
# mezcle solo los que coincidan y no me haga datos repetidos
contadorEstacionesDistintasTotales = pd.merge(contadorEstacionesDistintasIniciales,contadorEstacionesDistintasFinales,\
                                             on=['start_station_name','end_station_name'],how='inner')

# %%
# Defino una funcion para sumar los dos contadores
def sumarContadores(x):
    return x[2] + x[3]

# %%
# aplico la funcion en el dataframe para sumar las columnas de contadores asi devuelve una serie con los resultados
sumaDeContadores = contadorEstacionesDistintasTotales.apply(sumarContadores,axis=1)
contadorEstacionesDistintasTotales['contador'] = sumaDeContadores

# %%
contadorEstacionesDistintasTotales.head(10)
# Out:
#                          start_station_name  \
# 0   San Francisco Caltrain 2 (330 Townsend)
# 1      Harry Bridges Plaza (Ferry Building)
# 2                           Townsend at 7th
# 3                           2nd at Townsend
# 4      Harry Bridges Plaza (Ferry Building)
# 5                    Embarcadero at Sansome
# 6                     Embarcadero at Folsom
# 7                         Steuart at Market
# 8                         2nd at South Park
# 9  San Francisco Caltrain (Townsend at 4th)
#
#                            end_station_name  contador_x  contador_y  contador
# 0                           Townsend at 7th        6216        3495      9711
# 1                    Embarcadero at Sansome        6164        3231      9395
# 2  San Francisco Caltrain (Townsend at 4th)        5041        2320      7361
# 3      Harry Bridges Plaza (Ferry Building)        4839        4357      9196
# 4                           2nd at Townsend        4357        4839      9196
# 5                         Steuart at Market        4269        3116      7385
# 6  San Francisco Caltrain (Townsend at 4th)        3967        3031      6998
# 7                           2nd at Townsend        3903        2877      6780
# 8                         Market at Sansome        3627        3427      7054
# 9      Harry Bridges Plaza (Ferry Building)        3622        3033      6655

# %%
# saco las columnas que estan de mas
del contadorEstacionesDistintasTotales['contador_x']
del contadorEstacionesDistintasTotales['contador_y']

# %%
#Lo ordeno
contadorEstacionesDistintasTotales = contadorEstacionesDistintasTotales.sort_values('contador',ascending=False)

# %%
## Recorro el dataframe para borrarles los que coinciden iniciales y finales
# Primero agrupo
grouped = contadorEstacionesDistintasTotales.groupby(['start_station_name','end_station_name'])
# Me creo otro dataframe
aBorrar = pd.DataFrame(contadorEstacionesDistintasTotales)
#Creo una lista vacia para ir agregando las estaciones ya cargadas
lista = []

for estacion,grupo in grouped:
#    print(estacion)
# Agarro la primera estacion y la "doy vuelta"
    estacionActual = (estacion[1],estacion[0])
# Si la estacion Actual (la que esta dada vuelta ) no esta en la lista la cargo, despues verifico si esta en el data frame
# la estacion a verificar y me quedo con los que no son iguales (Saco solo la que esta dada vuelta)
    if not(estacionActual) in lista:
        #Agrego a la lista
        lista.append(estacion)
        #Hago un loc para quedarme con la parte del dataframe que necesito
        aBorrar = aBorrar.loc[(estacion[0] != aBorrar['end_station_name'] ) | \
                    ((estacion[1] != aBorrar['start_station_name'])),:]

# %%
# Saco el top 10 de la cantidad de viajes entre distintas estaciones 
top10 = aBorrar.head(10)
top10
# Out:
#                           start_station_name  \
# 0    San Francisco Caltrain 2 (330 Townsend)
# 16                    Embarcadero at Sansome
# 3                            2nd at Townsend
# 5                     Embarcadero at Sansome
# 36  San Francisco Caltrain (Townsend at 4th)
# 8                          2nd at South Park
# 11  San Francisco Caltrain (Townsend at 4th)
# 6                      Embarcadero at Folsom
# 22                           2nd at Townsend
# 19      Harry Bridges Plaza (Ferry Building)
#
#                                  end_station_name  contador
# 0                                 Townsend at 7th      9711
# 16           Harry Bridges Plaza (Ferry Building)      9395
# 3            Harry Bridges Plaza (Ferry Building)      9196
# 5                               Steuart at Market      7385
# 36                                Townsend at 7th      7361
# 8                               Market at Sansome      7054
# 11  Temporary Transbay Terminal (Howard at Beale)      7036
# 6        San Francisco Caltrain (Townsend at 4th)      6998
# 22                              Steuart at Market      6780
# 19       San Francisco Caltrain (Townsend at 4th)      6655

# %%
plt.figure()
plt.title(' Top 10 Cantidad de viajes entre distintas estaciones')
top10.groupby(['start_station_name','end_station_name'])['contador'].sum().plot(kind='bar',figsize=(9,6))
plt.ylabel('Cantidad de viajes')
plt.xlabel('Viajes entre estaciones');

# %% [markdown]
# # Cambio de temperatures en el weather de °F a °C

# %%
#Cambio de grados Fahrenheit a grados Celcius
weather['max_temperature_f'] = weather['max_temperature_f'].map(lambda x: round((x-32)/1.8,1))
weather['min_temperature_f'] = weather['min_temperature_f'].map(lambda x: round((x-32)/1.8,1))
weather['mean_temperature_f'] = weather['mean_temperature_f'].map(lambda x: round((x-32)/1.8,1))

# %%
## Renombro las columnas
weather.rename(columns={'max_temperature_f' : 'max_temperature',\
                        'min_temperature_f' : 'min_temperature','mean_temperature_f' : 'mean_temperature'},inplace=True)

# %%
weather['date'] = pd.to_datetime(weather['date'])
weather['year'] = weather['date'].map(lambda x: x.year)
weather['month'] = weather['date'].map(lambda x: x.month)

# %%
weather.head(3)
# Out:
#         date  max_temperature  mean_temperature  min_temperature  \
# 0 2013-08-29             23.3              20.0             16.1
# 1 2013-08-30             25.6              20.6             15.6
# 2 2013-08-31             21.7              17.8             13.9
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
#
#    mean_humidity  min_humidity  ...   max_wind_Speed_mph  mean_wind_speed_mph  \
# 0           75.0          57.0  ...                 23.0                 11.0
# 1           70.0          50.0  ...                 29.0                 13.0
# 2           75.0          57.0  ...                 26.0                 15.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                28.0                     0          4.0     NaN
# 1                35.0                     0          2.0     NaN
# 2                31.0                     0          4.0     NaN
#
#    wind_dir_degrees  zip_code  year month
# 0             286.0     94107  2013     8
# 1             291.0     94107  2013     8
# 2             284.0     94107  2013     8
#
# [3 rows x 26 columns]

# %% [markdown]
# ## Relacion Zip Code de weather con las cuidades del station y mergeo con trip

# %%
station['city'].value_counts()
# Out:
# San Francisco    35
# San Jose         16
# Redwood City      7
# Mountain View     7
# Palo Alto         5
# Name: city, dtype: int64

# %%
weather['zip_code'].value_counts()
# 95113 San Jose
# 94301 Palo Alto
# 94107 San Francisco CA
# 94063 Redwood City
# 94041 Mountain View
# DATOS SACADOS POR GOOGLE MAPS
# Out:
# 95113    733
# 94301    733
# 94107    733
# 94063    733
# 94041    733
# Name: zip_code, dtype: int64

# %% [markdown]
# # Creacion de un dataframe de las cuidades y sus respectivos zip code

# %%
#Creo el dataframe con los zip code de cada cuidad para despues mergear
dato = { 'city' : ['San Jose','Palo Alto','San Francisco','Redwood City','Mountain View'],\
       'zip_code': [95113,94301,94107,94063,94041]}
cityZipCode = pd.DataFrame(dato)
cityZipCode
# Out:
#             city  zip_code
# 0       San Jose     95113
# 1      Palo Alto     94301
# 2  San Francisco     94107
# 3   Redwood City     94063
# 4  Mountain View     94041

# %% [markdown]
# #### Merge con los otros dataframes

# %%
# Veo cuantos registros tienen en total trips
trips.shape
# Out:
# (669959, 19)

# %%
#Mergeo asi consigo el zip
stationZip = pd.merge(station,cityZipCode,on='city',how='outer')

# %%
stationZip.head(3)
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
#
#        city installation_date  zip_code
# 0  San Jose          8/6/2013     95113
# 1  San Jose          8/5/2013     95113
# 2  San Jose          8/6/2013     95113

# %%
# Mergeo con weather asi consigo la ciudad ademas del zip code
weatherCity = pd.merge(weather,cityZipCode,on='zip_code',how='outer')
weatherCity.head(3)
# Out:
#         date  max_temperature  mean_temperature  min_temperature  \
# 0 2013-08-29             23.3              20.0             16.1
# 1 2013-08-30             25.6              20.6             15.6
# 2 2013-08-31             21.7              17.8             13.9
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
#
#    mean_humidity  min_humidity      ...        mean_wind_speed_mph  \
# 0           75.0          57.0      ...                       11.0
# 1           70.0          50.0      ...                       13.0
# 2           75.0          57.0      ...                       15.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                28.0                     0          4.0     NaN
# 1                35.0                     0          2.0     NaN
# 2                31.0                     0          4.0     NaN
#
#    wind_dir_degrees  zip_code  year  month           city
# 0             286.0     94107  2013      8  San Francisco
# 1             291.0     94107  2013      8  San Francisco
# 2             284.0     94107  2013      8  San Francisco
#
# [3 rows x 27 columns]

# %%
# Saco las columnas que quiero del stationZip
stationCityZip = stationZip.loc[:,['name','city','zip_code']]
stationCityZip.head(3)
# Out:
#                                 name      city  zip_code
# 0  San Jose Diridon Caltrain Station  San Jose     95113
# 1              San Jose Civic Center  San Jose     95113
# 2             Santa Clara at Almaden  San Jose     95113

# %%
#Hago dos estaciones uno de salida y otro de entrada, igual que en city y zip code
startStationCityZip = stationCityZip.rename( columns = { 'name'  : 'start_station_name',\
                                                        'city' : 'start_city','zip_code' : 'start_zip_code'})
endStationCityZip = stationCityZip.rename( columns = { 'name'  : 'end_station_name',\
                                                        'city' : 'end_city','zip_code' : 'end_zip_code'})

# %%
startStationCityZip.head(3)
# Out:
#                   start_station_name start_city  start_zip_code
# 0  San Jose Diridon Caltrain Station   San Jose           95113
# 1              San Jose Civic Center   San Jose           95113
# 2             Santa Clara at Almaden   San Jose           95113

# %%
endStationCityZip.head(3)
# Out:
#                     end_station_name  end_city  end_zip_code
# 0  San Jose Diridon Caltrain Station  San Jose         95113
# 1              San Jose Civic Center  San Jose         95113
# 2             Santa Clara at Almaden  San Jose         95113

# %% [markdown]
# #### Se mergea startStationCityZip y endStationCityZip con el trip

# %%
#Ahora hago merge con el trip de la estacion de inicio
tripCityZip = pd.merge(trips,startStationCityZip,on='start_station_name',how='inner')
tripCityZip.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4299        83  8/29/2013 12:02  South Van Ness at Market
# 2  4760       113  8/29/2013 17:01  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                66  8/29/2013 12:04            Market at 10th
# 2                66  8/29/2013 17:03  South Van Ness at Market
#
#    end_station_id  bike_id subscription_type      ...        date_start  \
# 0              66      520        Subscriber      ...        2013-08-29
# 1              67      319        Subscriber      ...        2013-08-29
# 2              66      553        Subscriber      ...        2013-08-29
#
#   time_start   date_end time_end day_start hour_start  month_start_name  \
# 0      14:13 2013-08-29    14:14  Thursday         14            August
# 1      12:02 2013-08-29    12:04  Thursday         12            August
# 2      17:01 2013-08-29    17:03  Thursday         17            August
#
#   month_start     start_city start_zip_code
# 0           8  San Francisco          94107
# 1           8  San Francisco          94107
# 2           8  San Francisco          94107
#
# [3 rows x 21 columns]

# %%
#Hago lo mismo que lo anterior mergeo para sacar la ciudad de la estacion final y su zip code
tripCityZip = pd.merge(tripCityZip,endStationCityZip,on='end_station_name',how='inner')
tripCityZip.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4760       113  8/29/2013 17:01  South Van Ness at Market
# 2  5070       168  8/29/2013 21:43  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                66  8/29/2013 17:03  South Van Ness at Market
# 2                66  8/29/2013 21:46  South Van Ness at Market
#
#    end_station_id  bike_id subscription_type     ...        date_end time_end  \
# 0              66      520        Subscriber     ...      2013-08-29    14:14
# 1              66      553        Subscriber     ...      2013-08-29    17:03
# 2              66      598        Subscriber     ...      2013-08-29    21:46
#
#   day_start hour_start month_start_name month_start     start_city  \
# 0  Thursday         14           August           8  San Francisco
# 1  Thursday         17           August           8  San Francisco
# 2  Thursday         21           August           8  San Francisco
#
#   start_zip_code       end_city end_zip_code
# 0          94107  San Francisco        94107
# 1          94107  San Francisco        94107
# 2          94107  San Francisco        94107
#
# [3 rows x 23 columns]

# %%
tripCityZip.shape
# Out:
# (647025, 23)

# %% [markdown]
# #### Al hacer merge del trip con station se ve que desaparecen varios registros debido a que debe haber estaciones que estan en el trip que no aparecen en el station

# %%
estacionesTrip = trips['start_station_name'].value_counts()
estacionesTrip
# Out:
# San Francisco Caltrain (Townsend at 4th)         49092
# San Francisco Caltrain 2 (330 Townsend)          33742
# Harry Bridges Plaza (Ferry Building)             32934
# Embarcadero at Sansome                           27713
# Temporary Transbay Terminal (Howard at Beale)    26089
# 2nd at Townsend                                  25837
# Steuart at Market                                24838
# Market at Sansome                                24172
# Townsend at 7th                                  23724
# Market at 10th                                   20272
# Market at 4th                                    20165
# 2nd at South Park                                18496
# Powell Street BART                               18378
# Grant Avenue at Columbus Avenue                  16306
# 2nd at Folsom                                    15940
# Beale at Market                                  15709
# Embarcadero at Bryant                            14811
# Civic Center BART (7th at Market)                14102
# Embarcadero at Folsom                            14054
# 5th at Howard                                    13526
# Howard at 2nd                                    13163
# South Van Ness at Market                         12880
# Powell at Post (Union Square)                    12496
# Mechanics Plaza (Market at Battery)              12224
# Spear at Folsom                                  11949
# Commercial at Montgomery                         11888
# Yerba Buena Center of the Arts (3rd @ Howard)    11251
# Embarcadero at Vallejo                           10592
# Broadway St at Battery St                        10310
# Clay at Battery                                   9994
#                                                  ...
# Castro Street and El Camino Real                  2035
# MLK Library                                       2034
# San Antonio Caltrain Station                      1990
# Japantown                                         1910
# San Antonio Shopping Center                       1818
# Ryland Park                                       1747
# San Salvador at 1st                               1692
# St James Park                                     1680
# Evelyn Park and Ride                              1667
# San Jose Civic Center                             1594
# Redwood City Caltrain Station                     1554
# University and Emerson                            1512
# Arena Green / SAP Center                          1496
# SJSU - San Salvador at 9th                        1473
# Washington at Kearney                             1472
# Cowper at University                              1374
# Adobe on Almaden                                  1257
# SJSU 4th at San Carlos                            1170
# Rengstorff Avenue / California Street             1129
# California Ave Caltrain Station                   1026
# Santa Clara County Civic Center                    840
# Park at Olive                                      750
# Stanford in Redwood City                           436
# Mezes Park                                         341
# Redwood City Medical Center                        311
# San Mateo County Center                            287
# Franklin at Maple                                  224
# Redwood City Public Library                        213
# Broadway at Main                                    67
# San Jose Government Center                          23
# Name: start_station_name, dtype: int64

# %%
estacionesDeStation = station['name'].value_counts()
estacionesDeStation
# Out:
# Powell Street BART                               1
# Broadway St at Battery St                        1
# California Ave Caltrain Station                  1
# Mechanics Plaza (Market at Battery)              1
# 2nd at Townsend                                  1
# Palo Alto Caltrain Station                       1
# San Pedro Square                                 1
# Arena Green / SAP Center                         1
# Mountain View Caltrain Station                   1
# Spear at Folsom                                  1
# Stanford in Redwood City                         1
# Park at Olive                                    1
# Embarcadero at Vallejo                           1
# Redwood City Medical Center                      1
# San Antonio Caltrain Station                     1
# Yerba Buena Center of the Arts (3rd @ Howard)    1
# Market at 4th                                    1
# 2nd at South Park                                1
# Mountain View City Hall                          1
# St James Park                                    1
# Post at Kearney                                  1
# Franklin at Maple                                1
# Beale at Market                                  1
# SJSU 4th at San Carlos                           1
# Paseo de San Antonio                             1
# Japantown                                        1
# San Mateo County Center                          1
# South Van Ness at Market                         1
# Castro Street and El Camino Real                 1
# San Francisco City Hall                          1
#                                                 ..
# Davis at Jackson                                 1
# Cowper at University                             1
# Golden Gate at Polk                              1
# Townsend at 7th                                  1
# Embarcadero at Folsom                            1
# Clay at Battery                                  1
# MLK Library                                      1
# Howard at 2nd                                    1
# Ryland Park                                      1
# University and Emerson                           1
# Santa Clara at Almaden                           1
# San Salvador at 1st                              1
# Mezes Park                                       1
# San Jose Diridon Caltrain Station                1
# Redwood City Caltrain Station                    1
# Evelyn Park and Ride                             1
# San Jose Civic Center                            1
# Civic Center BART (7th at Market)                1
# Embarcadero at Sansome                           1
# San Francisco Caltrain 2 (330 Townsend)          1
# Santa Clara County Civic Center                  1
# San Francisco Caltrain (Townsend at 4th)         1
# Rengstorff Avenue / California Street            1
# San Antonio Shopping Center                      1
# 2nd at Folsom                                    1
# Market at Sansome                                1
# Washington at Kearney                            1
# Adobe on Almaden                                 1
# Redwood City Public Library                      1
# Temporary Transbay Terminal (Howard at Beale)    1
# Name: name, dtype: int64

# %%
indiceStationName = pd.Index(estacionesDeStation.reset_index()['index'])

# %%
indiceStationTripName = pd.Index(estacionesTrip.reset_index()['index'])

# %% [markdown]
# #### Estas serian las 4 estaciones que no tienen similitud en los dataset

# %%
indiceStationTripName.difference(indiceStationName)
# Out:
# Index([u'Broadway at Main', u'Post at Kearny', u'San Jose Government Center',
#        u'Washington at Kearny'],
#       dtype='object', name=u'index')

# %% [markdown]
# # Nota personal --->> HASTA ACA JUNTE LOS 4 PRIMEROS NOTEBOOKS

# %% [markdown]
# # Top 10 estacion id de entrada y salida

# %%
#Dame las 10 estaciones que mas veces se usaron como partida
tripCityZip['quantity_start_station_per_id'] = 1

# %%
#Las 10 estaciones de salida mas usadas 
grupo = tripCityZip.groupby('start_station_id').agg('count')\
            .sort_values('id', ascending = False)
topEstacionesSalida = grupo.loc[:,['id']].head(10)
topEstacionesSalida
# Out:
#                      id
# start_station_id
# 70                48172
# 69                33056
# 50                32417
# 60                27241
# 55                25653
# 61                25412
# 74                24550
# 77                23988
# 65                23381
# 76                19863

# %%
#idem con las estaciones de llegada
grupo = tripCityZip.groupby('end_station_id').agg('count')\
            .sort_values('id', ascending = False)
topEstacionesLlegada = grupo.loc[:,['id']].head(10)
topEstacionesLlegada
# Out:
#                    id
# end_station_id
# 70              62343
# 69              34518
# 50              32614
# 60              30186
# 61              28269
# 77              27818
# 65              26232
# 74              24672
# 55              22694
# 76              19577

# %%
plt.title('Top ten de las 10 estaciones que mas llegadas tienen', color = 'Black')
topEstacionesLlegada['id']\
    .plot(kind = 'bar', figsize = (12,8));
plt.xlabel('ID de estacion')
plt.ylabel('Cantidad de bicis que llegaron por estacion');

# %%
plt.title('Top ten de las 10 estaciones que mas salidas tienen', color = 'Black')
topEstacionesSalida['id']\
    .plot(kind = 'bar', figsize = (12,8));
plt.xlabel('ID de estacion') 
plt.ylabel('Cantidad de bicis que salieron por estacion');

# %% [markdown]
# # Anio donde hubo mas bicicletas alquiladas/viajes

# %%
tripCityZip['year_start'] = tripCityZip['date_start'].map(lambda x: x.year)
tripCityZip.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4760       113  8/29/2013 17:01  South Van Ness at Market
# 2  5070       168  8/29/2013 21:43  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                66  8/29/2013 17:03  South Van Ness at Market
# 2                66  8/29/2013 21:46  South Van Ness at Market
#
#    end_station_id  bike_id subscription_type    ...      day_start hour_start  \
# 0              66      520        Subscriber    ...       Thursday         14
# 1              66      553        Subscriber    ...       Thursday         17
# 2              66      598        Subscriber    ...       Thursday         21
#
#   month_start_name month_start     start_city start_zip_code       end_city  \
# 0           August           8  San Francisco          94107  San Francisco
# 1           August           8  San Francisco          94107  San Francisco
# 2           August           8  San Francisco          94107  San Francisco
#
#   end_zip_code  quantity_start_station_per_id year_start
# 0        94107                              1       2013
# 1        94107                              1       2013
# 2        94107                              1       2013
#
# [3 rows x 25 columns]

# %%
cantidadPorAnio = tripCityZip['year_start'].value_counts().sort_index()
cantidadPorAnio
# Out:
# 2013    100501
# 2014    313752
# 2015    232772
# Name: year_start, dtype: int64

# %%
plt.title('Cantidad de bicicletas alquiladas por anios')
cantidadPorAnio.plot('bar',figsize=(14,5))
plt.xlabel('Anios')
plt.ylabel('Cantidad de bicicletas alquiladas');

# %%
#Histograma sobre la variacion de la duracion de los viajes en San Francisco
#
dfSanFransisco = tripCityZip.loc[tripCityZip.start_city.str.contains('San Francisco'),:]\
                            .loc[tripCityZip.end_city.str.contains('San Francisco')]

# %%
plt.figure()
dfSanFransisco['duration'][0:10].hist(bins = 100, figsize = (10,6));
