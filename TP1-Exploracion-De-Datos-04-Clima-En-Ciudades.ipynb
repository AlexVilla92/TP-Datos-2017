# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weather = pd.read_csv('tp_bike/weather.csv')

# %%
len(weather)
# Out:
# 3665

# %%
station = pd.read_csv('tp_bike/station.csv')

# %%
station['city'].value_counts()
# Out:
# San Francisco    35
# San Jose         16
# Redwood City      7
# Mountain View     7
# Palo Alto         5
# Name: city, dtype: int64

# %%
station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
# id                   70 non-null int64
# name                 70 non-null object
# lat                  70 non-null float64
# long                 70 non-null float64
# dock_count           70 non-null int64
# city                 70 non-null object
# installation_date    70 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 3.0+ KB

# %%
weather.head(3)
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0  8/29/2013               74.0                68.0               61.0
# 1  8/30/2013               78.0                69.0               60.0
# 2  8/31/2013               71.0                64.0               57.0
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
#
#    mean_humidity  min_humidity   ...     mean_visibility_miles  \
# 0           75.0          57.0   ...                      10.0
# 1           70.0          50.0   ...                      10.0
# 2           75.0          57.0   ...                      10.0
#
#    min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                  10.0                23.0                 11.0
# ...

# %%
weather['date'].value_counts()
# Out:
# 10/24/2013    5
# 11/28/2014    5
# 11/28/2013    5
# 10/31/2013    5
# 10/14/2013    5
# 12/21/2014    5
# 9/14/2014     5
# 7/24/2015     5
# 5/18/2015     5
# 3/24/2014     5
# 1/18/2015     5
# 7/31/2014     5
# 6/2/2014      5
# 5/16/2014     5
# 5/28/2015     5
# 10/17/2014    5
# 1/18/2014     5
# 5/4/2015      5
# 3/19/2014     5
# 3/19/2015     5
# 6/10/2014     5
# 4/18/2014     5
# 1/11/2014     5
# 4/26/2015     5
# 12/21/2013    5
# 11/9/2013     5
# 2/23/2014     5
# 11/12/2013    5
# 8/19/2015     5
# 8/19/2014     5
#              ..
# 2/15/2015     5
# 10/22/2013    5
# 10/9/2014     5
# 4/18/2015     5
# 6/17/2015     5
# 8/13/2015     5
# 8/13/2014     5
# 2/20/2015     5
# 2/17/2014     5
# 1/16/2015     5
# 2/5/2014      5
# 10/30/2014    5
# 2/13/2015     5
# 10/30/2013    5
# 5/2/2015      5
# 11/27/2013    5
# 11/4/2014     5
# 5/27/2015     5
# 7/7/2014      5
# 9/17/2014     5
# 7/13/2015     5
# 10/4/2013     5
# 5/19/2015     5
# 11/11/2013    5
# ...

# %%
weather.dtypes
# Out:
# date                               object
# max_temperature_f                 float64
# mean_temperature_f                float64
# min_temperature_f                 float64
# max_dew_point_f                   float64
# mean_dew_point_f                  float64
# min_dew_point_f                   float64
# max_humidity                      float64
# mean_humidity                     float64
# min_humidity                      float64
# max_sea_level_pressure_inches     float64
# mean_sea_level_pressure_inches    float64
# min_sea_level_pressure_inches     float64
# max_visibility_miles              float64
# mean_visibility_miles             float64
# min_visibility_miles              float64
# max_wind_Speed_mph                float64
# mean_wind_speed_mph               float64
# max_gust_speed_mph                float64
# precipitation_inches               object
# cloud_cover                       float64
# events                             object
# ...

# %%
#agarro una fecha puntual
weather.loc[weather.date.str.contains('10/4/2014')]
#hay 5 registros por fecha, es decir un reporte de temperatura
#por cada ciudad
# Out:
#            date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 1873  10/4/2014               92.0                74.0               55.0
# 2238  10/4/2014               91.0                76.0               60.0
# 2603  10/4/2014               89.0                71.0               53.0
# 2968  10/4/2014               91.0                74.0               57.0
# 3333  10/4/2014               92.0                75.0               58.0
#
#       max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 1873             55.0              46.0             40.0          73.0
# 2238             64.0              43.0             28.0          65.0
# 2603             63.0              55.0             46.0          77.0
# 2968             57.0              46.0             36.0          55.0
# 3333             49.0              41.0             32.0          56.0
#
#       mean_humidity  min_humidity   ...     mean_visibility_miles  \
# ...

# %%
weather['zip_code'].value_counts()
#como hago para saber que codigo le pertenece a cada ciudad
# 95113 San Jose
# 94301 Palo Alto
# 94107 San Francisco CA
# 94063 Redwood City
# 94041 Mountain View
# Out:
# 95113    733
# 94301    733
# 94107    733
# 94063    733
# 94041    733
# Name: zip_code, dtype: int64

# %%
#Cada codigo postal, pertenece a una ciudad. Hay 5 ciudades
#PREGUNTA: Puede el clima de una ciudad influenciar en la cantidad de 
#viajes que se relizen? la logica indicaria que si, pues es mejor andar
#en bici un dia soleado que un dia con mucho frio y lluvia

#Analizo un poco el clima en cada ciudad
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665 entries, 0 to 3664
# Data columns (total 24 columns):
# date                              3665 non-null object
# max_temperature_f                 3661 non-null float64
# mean_temperature_f                3661 non-null float64
# min_temperature_f                 3661 non-null float64
# max_dew_point_f                   3611 non-null float64
# mean_dew_point_f                  3611 non-null float64
# min_dew_point_f                   3611 non-null float64
# max_humidity                      3611 non-null float64
# mean_humidity                     3611 non-null float64
# min_humidity                      3611 non-null float64
# max_sea_level_pressure_inches     3664 non-null float64
# mean_sea_level_pressure_inches    3664 non-null float64
# min_sea_level_pressure_inches     3664 non-null float64
# max_visibility_miles              3652 non-null float64
# mean_visibility_miles             3652 non-null float64
# ...

# %%
print(weather[pd.to_numeric(weather.max_temperature_f, errors = 'errors')\
       .isnull()]['max_temperature_f'])
print(weather[pd.to_numeric(weather.mean_temperature_f, errors = 'errors')\
       .isnull()]['mean_temperature_f'])
print(weather[pd.to_numeric(weather.min_temperature_f, errors = 'errors')\
       .isnull()]['min_temperature_f'])
#Cuatro valores nulos, los borro, los dejo?
#no hay registro de temperatura de esos dias
# Out:
# 2911   NaN
# 3177   NaN
# 3178   NaN
# 3179   NaN
# Name: max_temperature_f, dtype: float64
# 2911   NaN
# 3177   NaN
# 3178   NaN
# 3179   NaN
# Name: mean_temperature_f, dtype: float64
# 2911   NaN
# 3177   NaN
# 3178   NaN
# 3179   NaN
# Name: min_temperature_f, dtype: float64

# %%
#PREGUNTA EXISTENCIAL: habra alguna forma de vincular el zip_code con el 
#nombre de cada ciudad respectiva

#Cambio de grados Fahrenheit a grados Celcius
weather['max_temperature_f'] = weather['max_temperature_f'].map(lambda x: round((x-32)/1.8,1))
weather['min_temperature_f'] = weather['min_temperature_f'].map(lambda x: round((x-32)/1.8,1))
weather['mean_temperature_f'] = weather['mean_temperature_f'].map(lambda x: round((x-32)/1.8,1))

# %%
import calendar
weather['date'] = pd.to_datetime(weather['date'])

# %%
weather['year'] = weather['date'].map(lambda x: x.year)

# %%
weather['month'] = weather['date'].map(lambda x: x.month)

# %%
weather.head(3)
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0 2013-08-29               23.3                20.0               16.1
# 1 2013-08-30               25.6                20.6               15.6
# 2 2013-08-31               21.7                17.8               13.9
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
#
#    mean_humidity  min_humidity  ...   max_wind_Speed_mph  mean_wind_speed_mph  \
# 0           75.0          57.0  ...                 23.0                 11.0
# 1           70.0          50.0  ...                 29.0                 13.0
# 2           75.0          57.0  ...                 26.0                 15.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# ...

# %%
## Renombro las columnas
weather.rename(columns={'max_temperature_f' : 'max_temperature',\
                        'min_temperature_f' : 'min_temperature','mean_temperature_f' : 'mean_temperature'},inplace=True)

# %%
weather[2911:2912]
# Out:
#            date  max_temperature  mean_temperature  min_temperature  \
# 2911 2015-08-08              NaN               NaN              NaN
#
#       max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 2911              NaN               NaN              NaN           NaN
#
#       mean_humidity  min_humidity  ...   max_wind_Speed_mph  \
# 2911            NaN           NaN  ...                  NaN
#
#       mean_wind_speed_mph  max_gust_speed_mph  precipitation_inches  \
# 2911                  NaN                 NaN                   NaN
#
#       cloud_cover  events  wind_dir_degrees  zip_code  year month
# 2911          NaN     NaN               NaN     94301  2015     8
#
# [1 rows x 26 columns]

# %%
#quiero ver la variacion de temperatura por ciudad
city1_2014 = weather.loc[weather['year'] == 2015,:].groupby('zip_code').get_group(95113)

# %%
#lo queria hacer es en el eje x el tiempo, y en el eje y la temperatura
#entonces podria ver la variacion de la temperatura a traves de un
#tiempo determinado para una ciudad. Pero parece que discontinuidades en los mese
city1_2014.groupby('month')['mean_temperature'].plot(figsize = (10,8));

# %%
## Analizo que seria cloud cover 
weather['cloud_cover'].value_counts()
# Tiene una escala de 0 para soleado y 8 todo nublado
# Out:
# 0.0    834
# 1.0    490
# 2.0    478
# 3.0    474
# 4.0    456
# 5.0    400
# 6.0    283
# 7.0    180
# 8.0     69
# Name: cloud_cover, dtype: int64

# %%
weather['events'].value_counts()
# Out:
# Rain                 388
# Fog                  112
# Fog-Rain              17
# Rain-Thunderstorm      3
# rain                   2
# Name: events, dtype: int64

# %%
station = pd.read_csv('tp_bike/station.csv')

# %%
station.head(3)
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
#
#        city installation_date
# 0  San Jose          8/6/2013
# 1  San Jose          8/5/2013
# 2  San Jose          8/6/2013

# %%
station['city'].value_counts()
# 95113 San Jose
# 94301 Palo Alto
# 94107 San Francisco CA
# 94063 Redwood City
# 94041 Mountain View
# Out:
# San Francisco    35
# San Jose         16
# Redwood City      7
# Mountain View     7
# Palo Alto         5
# Name: city, dtype: int64

# %% [markdown]
# # Creacion de un dataframe de las cuidades y sus respectivos zip code

# %%
#Creo el dataframe con los zip code de cada cuidad para despues mergear
dato = { 'city' : ['San Jose','Palo Alto','San Francisco','Redwood City','Mountain View'],\
       'zip_code': [95113,94301,94107,94063,94041]}
cityZipCode = pd.DataFrame(dato)
cityZipCode
# Out:
#             city  zip_code
# 0       San Jose     95113
# 1      Palo Alto     94301
# 2  San Francisco     94107
# 3   Redwood City     94063
# 4  Mountain View     94041

# %% [markdown]
# # Merge con los otros dataframes

# %%
#Mergeo asi consigo el zip
stationZip = pd.merge(station,cityZipCode,on='city',how='outer')

# %%
stationZip
# Out:
#     id                                           name        lat        long  \
# 0    2              San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1    3                          San Jose Civic Center  37.330698 -121.888979
# 2    4                         Santa Clara at Almaden  37.333988 -121.894902
# 3    5                               Adobe on Almaden  37.331415 -121.893200
# 4    6                               San Pedro Square  37.336721 -121.894074
# 5    7                           Paseo de San Antonio  37.333798 -121.886943
# 6    8                            San Salvador at 1st  37.330165 -121.885831
# 7    9                                      Japantown  37.348742 -121.894715
# 8   10                             San Jose City Hall  37.337391 -121.886995
# 9   11                                    MLK Library  37.335885 -121.885660
# 10  12                         SJSU 4th at San Carlos  37.332808 -121.883891
# ...

# %%
# Mergeo con weather asi consigo la ciudad ademas del zip code
weatherCity = pd.merge(weather,cityZipCode,on='zip_code',how='outer')

# %%
weatherCity
# Out:
#            date  max_temperature  mean_temperature  min_temperature  \
# 0    2013-08-29             23.3              20.0             16.1
# 1    2013-08-30             25.6              20.6             15.6
# 2    2013-08-31             21.7              17.8             13.9
# 3    2013-09-01             23.3              18.9             14.4
# 4    2013-09-02             23.9              20.6             16.7
# 5    2013-09-03             22.8              19.4             15.6
# 6    2013-09-04             23.3              20.0             16.1
# 7    2013-09-05             22.2              18.9             15.6
# 8    2013-09-06             29.4              21.7             13.3
# 9    2013-09-07             31.1              22.8             14.4
# 10   2013-09-08             23.3              18.3             13.3
# 11   2013-09-09             24.4              18.9             12.8
# 12   2013-09-10             23.3              18.9             13.9
# ...

# %%
# Saco las columnas que quiero del stationZip
stationCityZip = stationZip.loc[:,['name','city','zip_code']]
stationCityZip
# Out:
#                                              name           city  zip_code
# 0               San Jose Diridon Caltrain Station       San Jose     95113
# 1                           San Jose Civic Center       San Jose     95113
# 2                          Santa Clara at Almaden       San Jose     95113
# 3                                Adobe on Almaden       San Jose     95113
# 4                                San Pedro Square       San Jose     95113
# 5                            Paseo de San Antonio       San Jose     95113
# 6                             San Salvador at 1st       San Jose     95113
# 7                                       Japantown       San Jose     95113
# 8                              San Jose City Hall       San Jose     95113
# 9                                     MLK Library       San Jose     95113
# 10                         SJSU 4th at San Carlos       San Jose     95113
# ...

# %%
#Hago dos estaciones uno de salida y otro de entrada, igual que en city y zip code
startStationCityZip = stationCityZip.rename( columns = { 'name'  : 'start_station_name',\
                                                        'city' : 'start_city','zip_code' : 'start_zip_code'})
endStationCityZip = stationCityZip.rename( columns = { 'name'  : 'end_station_name',\
                                                        'city' : 'end_city','zip_code' : 'end_zip_code'})

# %%
startStationCityZip
# Out:
#                                start_station_name     start_city  \
# 0               San Jose Diridon Caltrain Station       San Jose
# 1                           San Jose Civic Center       San Jose
# 2                          Santa Clara at Almaden       San Jose
# 3                                Adobe on Almaden       San Jose
# 4                                San Pedro Square       San Jose
# 5                            Paseo de San Antonio       San Jose
# 6                             San Salvador at 1st       San Jose
# 7                                       Japantown       San Jose
# 8                              San Jose City Hall       San Jose
# 9                                     MLK Library       San Jose
# 10                         SJSU 4th at San Carlos       San Jose
# 11                                  St James Park       San Jose
# 12                       Arena Green / SAP Center       San Jose
# ...

# %%
endStationCityZip
# Out:
#                                  end_station_name       end_city  end_zip_code
# 0               San Jose Diridon Caltrain Station       San Jose         95113
# 1                           San Jose Civic Center       San Jose         95113
# 2                          Santa Clara at Almaden       San Jose         95113
# 3                                Adobe on Almaden       San Jose         95113
# 4                                San Pedro Square       San Jose         95113
# 5                            Paseo de San Antonio       San Jose         95113
# 6                             San Salvador at 1st       San Jose         95113
# 7                                       Japantown       San Jose         95113
# 8                              San Jose City Hall       San Jose         95113
# 9                                     MLK Library       San Jose         95113
# 10                         SJSU 4th at San Carlos       San Jose         95113
# ...

# %% [markdown]
# # Levanto el trip para luego agregarle las areas de estaciones iniciales y finales con sus respectivos zip code

# %%
trip = pd.read_csv('tp_bike/trip.csv')

# %%
#Ahora hago merge con el trip de la estacion de inicio
tripCityZip = pd.merge(trip,startStationCityZip,on='start_station_name',how='outer')

# %%
tripCityZip
# Out:
#             id  duration        start_date        start_station_name  \
# 0         4576        63   8/29/2013 14:13  South Van Ness at Market
# 1         4299        83   8/29/2013 12:02  South Van Ness at Market
# 2         4760       113   8/29/2013 17:01  South Van Ness at Market
# 3         5070       168   8/29/2013 21:43  South Van Ness at Market
# 4         4765       228   8/29/2013 17:05  South Van Ness at Market
# 5         4560       237   8/29/2013 13:58  South Van Ness at Market
# 6         4559       242   8/29/2013 13:58  South Van Ness at Market
# 7         4584       262   8/29/2013 14:17  South Van Ness at Market
# 8         5075       348   8/29/2013 21:47  South Van Ness at Market
# 9         4981       399   8/29/2013 19:41  South Van Ness at Market
# 10        4455       431   8/29/2013 13:05  South Van Ness at Market
# 11        4808       572   8/29/2013 17:27  South Van Ness at Market
# 12        4398       607   8/29/2013 12:37  South Van Ness at Market
# ...

# %%
#Hago lo mismo que lo anterior mergeo para sacar la ciudad de la estacion final y su zip code
tripCityZip = pd.merge(tripCityZip,endStationCityZip,on='end_station_name',how='outer')

# %%
tripCityZip
# Out:
#             id  duration        start_date        start_station_name  \
# 0         4576        63   8/29/2013 14:13  South Van Ness at Market
# 1         4760       113   8/29/2013 17:01  South Van Ness at Market
# 2         5070       168   8/29/2013 21:43  South Van Ness at Market
# 3         4584       262   8/29/2013 14:17  South Van Ness at Market
# 4         4079       995    8/29/2013 9:35  South Van Ness at Market
# 5         4323      1397   8/29/2013 12:10  South Van Ness at Market
# 6         6393       134   8/30/2013 19:32  South Van Ness at Market
# 7         5947       140   8/30/2013 15:22  South Van Ness at Market
# 8         5744       182   8/30/2013 14:00  South Van Ness at Market
# 9         5774       481   8/30/2013 14:16  South Van Ness at Market
# 10        5240       497   8/30/2013 10:02  South Van Ness at Market
# 11        5988      1241   8/30/2013 15:35  South Van Ness at Market
# 12        5987      1298   8/30/2013 15:34  South Van Ness at Market
# ...

# %%
# Esto es opcional, lo quise sacar afuera nomas
tripCityZip.to_csv('tp_bike/tripCityZip.csv',index=False)
